# %%
# 📌 Step 0 — Environment setup and imports  
import sys
from pathlib import Path

# Go up one level from examples/ to the package root
sys.path.insert(0, str(Path.cwd().parent))
import os
import clifpy

from clifpy import Labs

# %%
# 📌 Step 1 — Load the Labs table  
# The `Labs.from_file` helper reads the Parquet files, attaches the DataFrame to  
# `labs.df`, and sets up logging & schema information automatically.

# Find the demo lab table shipped with the package
example_labs_dir = Path(clifpy.__file__).parent / "data" / "clif_demo"  

labs = Labs.from_file(
    data_directory=str(example_labs_dir),
    filetype="parquet",
    timezone="UTC"
)
# Out:
# 📢 Initialized labs table
# 📢 Data directory: /Users/dema/WD/clifpy/clifpy/data/clif_demo
# 📢 File type: parquet
# 📢 Timezone: UTC
# 📢 Output directory: /Users/dema/WD/clifpy/examples/output
# 📢 Loaded schema from /Users/dema/WD/clifpy/clifpy/schemas/labs_schema.yaml
# 📢 Loaded outlier configuration

# %%
# 📌 Step 2 — Reference Units Demo  
# Check and display lab reference units loaded from the schema (via Labs class property).
lab_reference_units_df = labs.get_lab_reference_units(save=True)
lab_reference_units_df
# Out:
# 📢 Saved lab reference units to /Users/dema/WD/clifpy/examples/output/lab_reference_units.csv
#               lab_category reference_unit  count
# 0                  albumin           g/dL    342
# 1     alkaline_phosphatase           IU/L    778
# 2                      alt           IU/L    786
# 3                      ast           IU/L    787
# 4       basophils_absolute           K/uL    249
# 5        basophils_percent              %    442
# 6              bicarbonate          mEq/L   2339
# 7     bilirubin_conjugated          mg/dL     43
# 8          bilirubin_total          mg/dL    803
# 9   bilirubin_unconjugated          mg/dL     38
# 10                     bun          mg/dL   2349
# 11         calcium_ionized          mg/dL    499
# 12           calcium_total          mg/dL   2099
# 13                chloride          mEq/L   2526
# 14              creatinine          mg/dL   2366
# 15                     crp           mg/L     26
# 16     eosinophils_percent              %    442
# 17                     esr          mm/hr      5
# 18                ferritin          ng/mL     44
# 19           glucose_serum          mg/dL   2538
# 20              hemoglobin           g/dL   2300
# 21                 lactate         mmol/L    638
# 22                     ldh           IU/L    477
# 23     lymphocytes_percent              %    442
# 24               magnesium          mg/dL   2237
# 25       monocytes_percent              %    442
# 26     neutrophils_percent              %    442
# 27           pco2_arterial          mm Hg    837
# 28           pco2_arterial           mmHg     40
# 29             pco2_venous           mmHg     89
# 30             ph_arterial          units    953
# 31               ph_venous          units    128
# 32               phosphate          mg/dL   2114
# 33          platelet_count           K/uL   2208
# 34            po2_arterial          mm Hg    837
# 35            po2_arterial           mmHg     38
# 36               potassium          mEq/L   2722
# 37                      pt            sec   1264
# 38                     ptt            sec   1316
# 39            so2_arterial              %    201
# 40      so2_central_venous              %     13
# 41        so2_mixed_venous              %    121
# 42                  sodium          mEq/L   2571
# 43           total_protein           g/dL     26
# 44              troponin_t           ng/L    197

# %%
from clifpy import Labs
import pandas as pd

labs = Labs(
    data_directory='tests/data',
    filetype='parquet'
)
# Load the test file manually
labs.df = pd.read_csv('../tests/data/test_labs_bad_units.csv')

# Standardize
labs.standardize_reference_units(save_mapping=True, lowercase=True)

# Check units after
print("\nAfter:")
print(labs.get_lab_reference_units())
# Out:
# 📢 Initialized labs table
# 📢 Data directory: tests/data
# 📢 File type: parquet
# 📢 Timezone: UTC
# 📢 Output directory: /Users/dema/WD/clifpy/examples/output
# 📢 Loaded schema from /Users/dema/WD/clifpy/clifpy/schemas/labs_schema.yaml
# 📢 Loaded outlier configuration
# 📢 Mapping '10^3/µL' -> '10^3/ul' for basophils_absolute
# 📢 Mapping '10^3/µL' -> '10^3/ul' for eosinophils_absolute
# 📢 Mapping '10^3/µL' -> '10^3/ul' for lymphocytes_absolute
# 📢 Mapping '10^3/µL' -> '10^3/ul' for monocytes_absolute
# 📢 Mapping '10^3/µL' -> '10^3/ul' for neutrophils_absolute
# 📢 Mapping '10^3/µL' -> '10^3/ul' for platelet_count
# 📢 Mapping '10^3/µL' -> '10^3/ul' for wbc
# 📢 Mapping 'K/uL' -> '10^3/ul' for basophils_absolute
# 📢 Mapping 'x10E3/uL' -> '10^3/ul' for basophils_absolute
# 📢 Mapping '10*3/uL' -> '10^3/ul' for basophils_absolute
# 📢 Mapping 'gm/dl' -> 'g/dl' for albumin
# 📢 Mapping 'iu/l' -> 'u/l' for alkaline_phosphatase
# 📢 Mapping 'iu/l' -> 'u/l' for alt
# 📢 Mapping 'mg/dl (calc)' -> 'mg/dl' for bilirubin_unconjugated
# 📢 Mapping 's' -> 'sec' for ptt
# 📢 Mapping 'second(s)' -> 'sec' for ptt
# 📢 Mapping 'mm[hg]' -> 'mmhg' for pco2_arterial
# 📢 Applied 17 unit standardizations
# ⚠️ Unmatched unit 'x10' for basophils_absolute. Expected one of: ['10^3/uL', '10^3/μL']
# ⚠️ Unmatched unit '%' for basophils_absolute. Expected one of: ['10^3/uL', '10^3/μL']
# ⚠️ Unmatched unit 'pg/mL' for troponin_i. Expected one of: ['ng/L']
# ⚠️ Unmatched unit 'mEq/L' for bicarbonate. Expected one of: ['mmol/L']
# ⚠️ Unmatched unit 'mmol/l' for calcium_ionized. Expected one of: ['mg/dL']
# 📢 Saved unit mappings to /Users/dema/WD/clifpy/examples/output/lab_unit_mappings.csv
#
# After:
#               lab_category reference_unit  count
# 0                  albumin           g/dl      3
# 1     alkaline_phosphatase            u/l      2
# 2                      alt            u/l      2
# 3                      ast            u/l      2
# 4       basophils_absolute              %      1
# 5       basophils_absolute        10^3/ul      5
# 6       basophils_absolute            x10      1
# 7        basophils_percent              %      1
# 8              bicarbonate          meq/l      1
# 9              bicarbonate         mmol/l      1
# 10    bilirubin_conjugated          mg/dl      1
# 11         bilirubin_total          mg/dl      1
# 12  bilirubin_unconjugated          mg/dl      2
# 13                     bun          mg/dl      1
# 14         calcium_ionized          mg/dl      1
# 15         calcium_ionized         mmol/l      1
# 16           calcium_total          mg/dl      1
# 17                chloride         mmol/l      1
# 18              creatinine          mg/dl      1
# 19                     crp           mg/l      1
# 20    eosinophils_absolute        10^3/ul      1
# 21     eosinophils_percent              %      1
# 22                     esr        mm/hour      1
# 23                ferritin          ng/ml      1
# 24     glucose_fingerstick          mg/dl      1
# 25           glucose_serum          mg/dl      1
# 26              hemoglobin           g/dl      1
# 27                     inr     (no units)      1
# 28                 lactate         mmol/l      1
# 29                     ldh            u/l      1
# 30    lymphocytes_absolute        10^3/ul      1
# 31     lymphocytes_percent              %      1
# 32               magnesium          mg/dl      1
# 33      monocytes_absolute        10^3/ul      1
# 34       monocytes_percent              %      1
# 35    neutrophils_absolute        10^3/ul      1
# 36     neutrophils_percent              %      1
# 37           pco2_arterial           mmhg      2
# 38             pco2_venous           mmhg      1
# 39             ph_arterial     (no units)      1
# 40               ph_venous     (no units)      1
# 41               phosphate          mg/dl      1
# 42          platelet_count        10^3/ul      1
# 43            po2_arterial           mmhg      1
# 44               potassium         mmol/l      1
# 45           procalcitonin          ng/ml      1
# 46                      pt            sec      1
# 47                     ptt            sec      3
# 48            so2_arterial              %      1
# 49      so2_central_venous              %      1
# 50        so2_mixed_venous              %      1
# 51                  sodium         mmol/l      1
# 52           total_protein           g/dl      1
# 53              troponin_i           ng/l      1
# 54              troponin_i          pg/ml      1
# 55              troponin_t           ng/l      1
# 56                     wbc        10^3/ul      1

# %%
# units_fixed = labs.standardize_reference_units(inplace=False)
